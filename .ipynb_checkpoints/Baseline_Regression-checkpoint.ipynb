# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime as dt
import statsmodels.api as sm
from arch import arch_model
from Utils import *

# %% [markdown]
# # SPX implied volatility data

# %%
spx_vol = pd.read_csv('processed_data/test.csv')

# %%
spx_vol.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1        10        30        60        91       122  \
# 0  2020-01-02         -90  0.000494  0.000381  0.000469  0.000476  0.000477
# 1  2020-01-02         -85  0.000431  0.000379  0.000457  0.000473  0.000478
# 2  2020-01-02         -80  0.000391  0.000384  0.000456  0.000477  0.000487
# 3  2020-01-02         -75  0.000379  0.000393  0.000463  0.000488  0.000501
# 4  2020-01-02         -70  0.000381  0.000405  0.000476  0.000503  0.000519
# 5  2020-01-02         -65  0.000386  0.000419  0.000492  0.000522  0.000539
# 6  2020-01-02         -60  0.000394  0.000436  0.000510  0.000543  0.000560
# 7  2020-01-02         -55  0.000404  0.000454  0.000532  0.000566  0.000584
# 8  2020-01-02         -50  0.000416  0.000475  0.000556  0.000593  0.000612
# 9  2020-01-02         -45  0.000430  0.000498  0.000583  0.000622  0.000643
#
#         152       182       273       365       547       730
# 0  0.000485  0.000490  0.000495  0.000502  0.000513  0.000527
# 1  0.000488  0.000494  0.000507  0.000517  0.000534  0.000549
# 2  0.000497  0.000505  0.000522  0.000533  0.000557  0.000577
# 3  0.000512  0.000519  0.000540  0.000553  0.000580  0.000606
# 4  0.000530  0.000537  0.000562  0.000576  0.000604  0.000632
# 5  0.000549  0.000557  0.000587  0.000602  0.000629  0.000657
# 6  0.000571  0.000579  0.000615  0.000631  0.000657  0.000683
# 7  0.000595  0.000604  0.000646  0.000663  0.000687  0.000711
# 8  0.000623  0.000633  0.000679  0.000697  0.000720  0.000741
# 9  0.000655  0.000666  0.000716  0.000734  0.000756  0.000775

# %% [markdown]
# # SPX price data

# %%
spx = pd.read_csv('data/SPX.csv', skiprows=2)

# %%
spx.shape
# Out:
# (9159, 6)

# %%
spx['Date'] = pd.to_datetime(spx['Date'], format='%m/%d/%Y')

# %%
spx["Return"] = convert_to_daily_returns(spx.Close)*100

# %%
spx["Year"] = spx['Date'].dt.to_period('Y')

# %%
spx.head(10)
# Out:
#         Date Ticker    Open    High     Low   Close    Return  Return_lag1  \
# 0 1986-01-02  _SPXD  211.24  211.28  208.93  209.59       NaN          NaN
# 1 1986-01-03  _SPXD  209.60  210.88  209.51  210.88  0.615487          NaN
# 2 1986-01-06  _SPXD  210.89  210.98  209.93  210.65 -0.109067     0.615487
# 3 1986-01-07  _SPXD  210.69  213.80  210.65  213.80  1.495371    -0.109067
# 4 1986-01-08  _SPXD  213.79  214.57  207.49  207.97 -2.726848     1.495371
# 5 1986-01-09  _SPXD  207.96  207.97  204.51  206.11 -0.894360    -2.726848
# 6 1986-01-10  _SPXD  206.17  207.33  205.52  205.96 -0.072777    -0.894360
# 7 1986-01-13  _SPXD  205.97  206.83  205.52  206.72  0.369004    -0.072777
# 8 1986-01-14  _SPXD  206.75  207.37  206.06  206.64 -0.038700     0.369004
# 9 1986-01-15  _SPXD  206.64  208.27  206.64  208.26  0.783972    -0.038700
#
#    Year
# 0  1986
# 1  1986
# 2  1986
# 3  1986
# 4  1986
# 5  1986
# 6  1986
# 7  1986
# 8  1986
# 9  1986

# %%
year_counts = pd.DataFrame(spx.iloc[1:].groupby(['Year']).size())
year_counts.columns = ['Count']
year_counts.reset_index()
year_counts.head()
# Out:
#       Count
# Year
# 1986    252
# 1987    253
# 1988    253
# 1989    252
# 1990    253

# %%
# Use the counts to calculate the position of our xticks
year_idx = year_counts['Count'].cumsum().shift() - 1
year_idx[0] = 0
year_idx = year_idx.convert_dtypes()
year_idx.head()
# Out:
# Year
# 1986       0
# 1987     251
# 1988     504
# 1989     757
# 1990    1009
# Freq: A-DEC, Name: Count, dtype: Int64

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 8))
ax.plot(spx["Return"].iloc[1:], linewidth=0.2)
fig.autofmt_xdate(rotation=90)
ax.set_xticks(year_idx)
ax.set_xticklabels(year_counts.index)
ax.set_xlabel('Year')
ax.set_ylabel('Return')
ax.grid(visible=True, which='major', linestyle='--')

# %% [markdown]
# # Baseline: Linear Regression

# %%
spx["Return_lag1"] = spx["Return"].shift(1)

# %%
spx.head(10)
# Out:
#         Date Ticker    Open    High     Low   Close    Return  Return_lag1
# 0 1986-01-02  _SPXD  211.24  211.28  208.93  209.59       NaN          NaN
# 1 1986-01-03  _SPXD  209.60  210.88  209.51  210.88  0.615487          NaN
# 2 1986-01-06  _SPXD  210.89  210.98  209.93  210.65 -0.109067     0.615487
# 3 1986-01-07  _SPXD  210.69  213.80  210.65  213.80  1.495371    -0.109067
# 4 1986-01-08  _SPXD  213.79  214.57  207.49  207.97 -2.726848     1.495371
# 5 1986-01-09  _SPXD  207.96  207.97  204.51  206.11 -0.894360    -2.726848
# 6 1986-01-10  _SPXD  206.17  207.33  205.52  205.96 -0.072777    -0.894360
# 7 1986-01-13  _SPXD  205.97  206.83  205.52  206.72  0.369004    -0.072777
# 8 1986-01-14  _SPXD  206.75  207.37  206.06  206.64 -0.038700     0.369004
# 9 1986-01-15  _SPXD  206.64  208.27  206.64  208.26  0.783972    -0.038700

# %%
ols_fit = sm.regression.linear_model.OLS(
    endog=spx["Return"].iloc[2:], exog=spx["Return_lag1"].iloc[2:]).fit()
# sm.formula.ols(formula = 'Return~Return_lag1', data=spx).fit()

# %%
print(ols_fit.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Return   R-squared (uncentered):                   0.005
# Model:                            OLS   Adj. R-squared (uncentered):              0.004
# Method:                 Least Squares   F-statistic:                              42.36
# Date:                Thu, 05 May 2022   Prob (F-statistic):                    8.01e-11
# Time:                        22:57:45   Log-Likelihood:                         -14344.
# No. Observations:                9157   AIC:                                  2.869e+04
# Df Residuals:                    9156   BIC:                                  2.870e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Return_lag1    -0.0679      0.010     -6.508      0.000      -0.088      -0.047
# ==============================================================================
# Omnibus:                     3211.200   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           170177.268
# Skew:                          -0.901   Prob(JB):                         0.00
# Kurtosis:                      24.042   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Baseline: GARCH

# %%
garch_fit = arch_model(
    y=spx["Return"].iloc[1:],
    p=1, q=1,
    mean='Constant',
    dist='studentst',
    rescale=True).fit(disp='off')
# Default: p=1, q=1, vol='GARCH', dist='normal'

# %%
garch_fit
# Out:
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                       Return   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -11988.9
# Distribution:      Standardized Student's t   AIC:                           23991.8
# Method:                  Maximum Likelihood   BIC:                           24041.6
#                                               No. Observations:                 9158
# Date:                      Thu, May 05 2022   Df Residuals:                     9157
# Time:                              23:15:53   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0771  7.421e-03     10.389  2.793e-25 [6.255e-02,9.163e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0213  5.876e-03      3.629  2.843e-04 [9.808e-03,3.284e-02]
# alpha[1]       0.0621  1.527e-02      4.069  4.721e-05 [3.220e-02,9.206e-02]
# alpha[2]       0.1004  3.230e-02      3.108  1.883e-03   [3.709e-02,  0.164]
# beta[1]        0.3764      0.447      0.842      0.400     [ -0.500,  1.253]
# beta[2]        0.4519      0.409      1.106      0.269     [ -0.349,  1.253]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             5.6890      0.365     15.605  6.758e-55 [  4.974,  6.404]
# ========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x7fa344bc18e0
